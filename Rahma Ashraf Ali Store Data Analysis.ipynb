# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"D:\Codex Ai Course\Sessions\Data Sets\Store.csv")
df
# Out:
#      Order_ID Product_Name     Category           Store        City  \
# 0       10001        Chair   Networking   Online Market       Tanta
# 1       10002       Webcam   Networking   Digital World        Giza
# 2       10003    USB Cable    Furniture  Computer House  Alexandria
# 3       10004   Headphones   Networking      Mega Store    Ismailia
# 4       10005          NaN  Electronics  Computer House       Luxor
# ..        ...          ...          ...             ...         ...
# 795     10796        Phone   Networking   Digital World       Cairo
# 796     10797      Printer   Networking             NaN    Mansoura
# 797     10798      Monitor    Furniture      Smart Shop  Alexandria
# 798     10799         Desk    Furniture             NaN       Tanta
# 799     10800     Keyboard   Networking      Smart Shop        Giza
#
#      Unit_Price  Quantity  Discount (%)  Stock  Rating Payment_Method  \
# 0        1824.0       1.0          10.0   44.0     2.5    Credit Card
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order_ID         800 non-null    int64
#  1   Product_Name     720 non-null    str
#  2   Category         720 non-null    str
#  3   Store            720 non-null    str
#  4   City             720 non-null    str
#  5   Unit_Price       720 non-null    float64
#  6   Quantity         720 non-null    float64
#  7   Discount (%)     720 non-null    float64
#  8   Stock            720 non-null    float64
#  9   Rating           720 non-null    float64
#  10  Payment_Method   720 non-null    str
#  11  Customer_Gender  720 non-null    str
#  12  Order_Date       800 non-null    str
# dtypes: float64(5), int64(1), str(7)
# memory usage: 81.4 KB

# %%
df.isna().sum()
# Out:
# Order_ID            0
# Product_Name       80
# Category           80
# Store              80
# City               80
# Unit_Price         80
# Quantity           80
# Discount (%)       80
# Stock              80
# Rating             80
# Payment_Method     80
# Customer_Gender    80
# Order_Date          0
# dtype: int64

# %%
df["Order_Date"]=pd.to_datetime(df["Order_Date"])
df
# Out:
#      Order_ID Product_Name     Category           Store        City  \
# 0       10001        Chair   Networking   Online Market       Tanta
# 1       10002       Webcam   Networking   Digital World        Giza
# 2       10003    USB Cable    Furniture  Computer House  Alexandria
# 3       10004   Headphones   Networking      Mega Store    Ismailia
# 4       10005          NaN  Electronics  Computer House       Luxor
# ..        ...          ...          ...             ...         ...
# 795     10796        Phone   Networking   Digital World       Cairo
# 796     10797      Printer   Networking             NaN    Mansoura
# 797     10798      Monitor    Furniture      Smart Shop  Alexandria
# 798     10799         Desk    Furniture             NaN       Tanta
# 799     10800     Keyboard   Networking      Smart Shop        Giza
#
#      Unit_Price  Quantity  Discount (%)  Stock  Rating Payment_Method  \
# 0        1824.0       1.0          10.0   44.0     2.5    Credit Card
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order_ID         800 non-null    int64
#  1   Product_Name     720 non-null    str
#  2   Category         720 non-null    str
#  3   Store            720 non-null    str
#  4   City             720 non-null    str
#  5   Unit_Price       720 non-null    float64
#  6   Quantity         720 non-null    float64
#  7   Discount (%)     720 non-null    float64
#  8   Stock            720 non-null    float64
#  9   Rating           720 non-null    float64
#  10  Payment_Method   720 non-null    str
#  11  Customer_Gender  720 non-null    str
#  12  Order_Date       800 non-null    datetime64[us]
# dtypes: datetime64[us](1), float64(5), int64(1), str(6)
# memory usage: 81.4 KB

# %%
df.describe(include="O")
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_20240\504318277.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include="O")
#        Product_Name     Category          Store   City Payment_Method  \
# count           720          720            720    720            720
# unique           20            5              8     10              5
# top         Printer  Electronics  Digital World  Tanta    Credit Card
# freq             47          151            106     85            170
#
#        Customer_Gender
# count              720
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order_ID         800 non-null    int64
#  1   Product_Name     720 non-null    str
#  2   Category         720 non-null    str
#  3   Store            720 non-null    str
#  4   City             720 non-null    str
#  5   Unit_Price       720 non-null    float64
#  6   Quantity         720 non-null    float64
#  7   Discount (%)     720 non-null    float64
#  8   Stock            720 non-null    float64
#  9   Rating           720 non-null    float64
#  10  Payment_Method   720 non-null    str
#  11  Customer_Gender  720 non-null    str
#  12  Order_Date       800 non-null    datetime64[us]
# dtypes: datetime64[us](1), float64(5), int64(1), str(6)
# memory usage: 81.4 KB

# %%
df= df.fillna( {
    "Product_Name":"Unknown",
    "Category":"Unknown",
    "Store": "Unknown",
    "City": "Unknown",
    "Unit_Price" :df["Unit_Price"].mean(),
    "Quantity" :df["Quantity"].mean(),
    "Discount (%)":df["Discount (%)"].mean(),
    "Stock":df["Stock"].mean(),
    "Rating":df["Rating"].median(),
    "Payment_Method" :"Unknown",
    "Customer_Gender":"Unknown"



    
    
     



} )

# %%
df
# Out:
#      Order_ID Product_Name     Category           Store        City  \
# 0       10001        Chair   Networking   Online Market       Tanta
# 1       10002       Webcam   Networking   Digital World        Giza
# 2       10003    USB Cable    Furniture  Computer House  Alexandria
# 3       10004   Headphones   Networking      Mega Store    Ismailia
# 4       10005      Unknown  Electronics  Computer House       Luxor
# ..        ...          ...          ...             ...         ...
# 795     10796        Phone   Networking   Digital World       Cairo
# 796     10797      Printer   Networking         Unknown    Mansoura
# 797     10798      Monitor    Furniture      Smart Shop  Alexandria
# 798     10799         Desk    Furniture         Unknown       Tanta
# 799     10800     Keyboard   Networking      Smart Shop        Giza
#
#      Unit_Price  Quantity  Discount (%)       Stock  Rating Payment_Method  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order_ID         800 non-null    int64
#  1   Product_Name     800 non-null    str
#  2   Category         800 non-null    str
#  3   Store            800 non-null    str
#  4   City             800 non-null    str
#  5   Unit_Price       800 non-null    float64
#  6   Quantity         800 non-null    float64
#  7   Discount (%)     800 non-null    float64
#  8   Stock            800 non-null    float64
#  9   Rating           800 non-null    float64
#  10  Payment_Method   800 non-null    str
#  11  Customer_Gender  800 non-null    str
#  12  Order_Date       800 non-null    datetime64[us]
# dtypes: datetime64[us](1), float64(5), int64(1), str(6)
# memory usage: 81.4 KB

# %%
df.isna().sum()
# Out:
# Order_ID           0
# Product_Name       0
# Category           0
# Store              0
# City               0
# Unit_Price         0
# Quantity           0
# Discount (%)       0
# Stock              0
# Rating             0
# Payment_Method     0
# Customer_Gender    0
# Order_Date         0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Length: 800, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#          Order_ID    Unit_Price    Quantity  Discount (%)       Stock  \
# count    800.0000    800.000000  800.000000    800.000000  800.000000
# mean   10400.5000  15200.405556    5.465278     15.673611  149.238889
# min    10001.0000     75.000000    1.000000      0.000000    0.000000
# 25%    10200.7500   8622.500000    3.000000     10.000000   85.000000
# 50%    10400.5000  15200.405556    5.465278     15.673611  149.238889
# 75%    10600.2500  21843.000000    8.000000     25.000000  215.250000
# max    10800.0000  29858.000000   10.000000     30.000000  299.000000
# std      231.0844   8177.508077    2.752887      9.630098   83.314586
#
#            Rating           Order_Date
# count  800.000000                  800
# mean     2.993750  2025-01-08 10:19:12
# min      1.000000  2024-01-01 00:00:00
# 25%      2.100000  2024-06-28 12:00:00
# 50%      3.000000  2025-01-10 12:00:00
# 75%      3.900000  2025-07-13 00:00:00
# max      5.000000  2025-12-30 00:00:00
# ...

# %%
df.describe(include="O")
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_20240\504318277.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include="O")
#        Product_Name     Category          Store   City Payment_Method  \
# count           800          800            800    800            800
# unique           21            6              9     11              6
# top         Unknown  Electronics  Digital World  Tanta    Credit Card
# freq             80          151            106     85            170
#
#        Customer_Gender
# count              800
# ...

# %%
df["Product_Name"].value_counts()
# Out:
# Product_Name
# Unknown        80
# Printer        47
# Mouse          45
# Laptop         42
# Hard Drive     42
# SSD            42
# USB Cable      40
# Speaker        40
# Microphone     39
# Chair          35
# Phone          35
# Smart Watch    35
# Monitor        34
# Tablet         34
# Webcam         33
# Keyboard       32
# Desk           32
# Camera         31
# Power Bank     28
# Headphones     27
# Router         27
# Name: count, dtype: int64

# %%
list(df["Product_Name"].unique())
# Out:
# ['Chair',
#  'Webcam',
#  'USB Cable',
#  'Headphones',
#  'Unknown',
#  'Microphone',
#  'Monitor',
#  'Phone',
#  'Mouse',
#  'Keyboard',
#  'Speaker',
#  'Desk',
#  'Laptop',
#  'Hard Drive',
#  'Camera',
#  'SSD',
#  'Printer',
#  'Tablet',
#  'Router',
#  'Power Bank',
#  'Smart Watch']

# %%
df
# Out:
#      Order_ID Product_Name     Category           Store        City  \
# 0       10001        Chair   Networking   Online Market       Tanta
# 1       10002       Webcam   Networking   Digital World        Giza
# 2       10003    USB Cable    Furniture  Computer House  Alexandria
# 3       10004   Headphones   Networking      Mega Store    Ismailia
# 4       10005      Unknown  Electronics  Computer House       Luxor
# ..        ...          ...          ...             ...         ...
# 795     10796        Phone   Networking   Digital World       Cairo
# 796     10797      Printer   Networking         Unknown    Mansoura
# 797     10798      Monitor    Furniture      Smart Shop  Alexandria
# 798     10799         Desk    Furniture         Unknown       Tanta
# 799     10800     Keyboard   Networking      Smart Shop        Giza
#
#      Unit_Price  Quantity  Discount (%)       Stock  Rating Payment_Method  \
# ...

# %%
list(df["Category"].unique())
# Out:
# ['Networking', 'Furniture', 'Electronics', 'Unknown', 'Accessories', 'Office']

# %%
list(df["Store"].unique())
# Out:
# ['Online Market',
#  'Digital World',
#  'Computer House',
#  'Mega Store',
#  'Unknown',
#  'Elite Store',
#  'Smart Shop',
#  'Tech Zone',
#  'Future Electronics']

# %%
list(df["City"].unique())
# Out:
# ['Tanta',
#  'Giza',
#  'Alexandria',
#  'Ismailia',
#  'Luxor',
#  'Aswan',
#  'Unknown',
#  'Port Said',
#  'Mansoura',
#  'Suez',
#  'Cairo']

# %%
list(df["Payment_Method"].unique())
# Out:
# ['Credit Card', 'Debit Card', 'Vodafone Cash', 'Unknown', 'Cash', 'Instapay']

# %%
list(df["Customer_Gender"].unique())
# Out:
# ['Male', 'Female', 'Unknown']

# %%
tolal_Revenue=df['Total_Sales'] = df['Unit_Price'] * df['Quantity'] * (1 - df['Discount (%)']/100)
tolal_Revenue
# Out:
# 0        1641.600000
# 1       19261.800000
# 2        4728.000000
# 3       24201.000000
# 4      122386.697917
#            ...
# 795     12576.900000
# 796     39814.200000
# 797     10390.800000
# 798      7035.000000
# 799     61933.200000
# Length: 800, dtype: float64

# %%
df['Year'] = df['Order_Date'].dt.year
df['Month'] = df['Order_Date'].dt.month
print(df[['Total_Sales','Year','Month']].head(10))
# Out:
#      Total_Sales  Year  Month
# 0    1641.600000  2025      4
# 1   19261.800000  2024      4
# 2    4728.000000  2024      1
# 3   24201.000000  2025      6
# 4  122386.697917  2024      5
# 5   17361.000000  2024      7
# 6   62868.750000  2025      6
# 7   49102.200000  2025      1
# 8  124215.600000  2025      5
# 9   91852.800000  2024      6

# %% [markdown]
# **Which category generates the most revenue?**

# %%
print(df.groupby('Category')['Total_Sales'].sum().sort_values(ascending=False))
# Out:
# Category
# Electronics    1.128999e+07
# Office         1.115272e+07
# Furniture      9.909402e+06
# Accessories    9.683172e+06
# Networking     8.555617e+06
# Unknown        5.858916e+06
# Name: Total_Sales, dtype: float64

# %% [markdown]
# **What is the best-selling product in terms of volume?**

# %%
print(df.groupby('Product_Name')['Quantity'].sum().sort_values(ascending=False))
# Out:
# Product_Name
# Unknown        376.722222
# Mouse          262.395833
# Printer        260.395833
# USB Cable      233.930556
# Microphone     232.791667
# Laptop         232.256944
# Speaker        225.861111
# Chair          211.791667
# Smart Watch    209.256944
# Hard Drive     205.930556
# Tablet         195.930556
# Webcam         192.395833
# Monitor        189.000000
# Phone          185.395833
# SSD            182.465278
# Desk           176.861111
# Keyboard       172.930556
# Router         164.326389
# Headphones     155.326389
# Camera         154.395833
# Power Bank     151.861111
# Name: Quantity, dtype: float64

# %% [markdown]
# **Which city is the most expensive?**

# %%
print(df.groupby('City')['Total_Sales'].sum().sort_values(ascending=False))
# Out:
# City
# Unknown       6.220732e+06
# Luxor         5.981264e+06
# Tanta         5.709231e+06
# Mansoura      5.597422e+06
# Aswan         5.439242e+06
# Suez          5.286350e+06
# Giza          5.285413e+06
# Ismailia      4.663468e+06
# Cairo         4.336042e+06
# Port Said     4.011898e+06
# Alexandria    3.918753e+06
# Name: Total_Sales, dtype: float64

# %%
print(df.groupby('Category')[['Unit_Price', 'Quantity']].mean())
# Out:
#                Unit_Price  Quantity
# Category
# Accessories  14910.383110  5.254428
# Electronics  14779.832303  5.896523
# Furniture    14119.101323  5.503732
# Networking   15725.150347  4.887912
# Office       16459.839157  5.627443
# Unknown      15398.985833  5.603212

# %%
print(df.groupby('Product_Name')['Quantity'].sum().sort_values(ascending=False))
# Out:
# Product_Name
# Unknown        376.722222
# Mouse          262.395833
# Printer        260.395833
# USB Cable      233.930556
# Microphone     232.791667
# Laptop         232.256944
# Speaker        225.861111
# Chair          211.791667
# Smart Watch    209.256944
# Hard Drive     205.930556
# Tablet         195.930556
# Webcam         192.395833
# Monitor        189.000000
# Phone          185.395833
# SSD            182.465278
# Desk           176.861111
# Keyboard       172.930556
# Router         164.326389
# Headphones     155.326389
# Camera         154.395833
# Power Bank     151.861111
# Name: Quantity, dtype: float64

# %%
print(df['Product_Name'].mode()[0])
print(df['Product_Name'].value_counts())
# Out:
# Unknown
# Product_Name
# Unknown        80
# Printer        47
# Mouse          45
# Laptop         42
# Hard Drive     42
# SSD            42
# USB Cable      40
# Speaker        40
# Microphone     39
# Chair          35
# Phone          35
# Smart Watch    35
# Monitor        34
# Tablet         34
# Webcam         33
# Keyboard       32
# Desk           32
# Camera         31
# Power Bank     28
# Headphones     27
# Router         27
# Name: count, dtype: int64

# %%
print(df.groupby('City')['Total_Sales'].sum().sort_values(ascending=False))
# Out:
# City
# Unknown       6.220732e+06
# Luxor         5.981264e+06
# Tanta         5.709231e+06
# Mansoura      5.597422e+06
# Aswan         5.439242e+06
# Suez          5.286350e+06
# Giza          5.285413e+06
# Ismailia      4.663468e+06
# Cairo         4.336042e+06
# Port Said     4.011898e+06
# Alexandria    3.918753e+06
# Name: Total_Sales, dtype: float64

# %%
print(df['City'].mode()[0])
print(df['City'].value_counts())
# Out:
# Tanta
# City
# Tanta         85
# Giza          80
# Unknown       80
# Luxor         79
# Mansoura      77
# Aswan         75
# Suez          68
# Cairo         68
# Port Said     67
# Ismailia      63
# Alexandria    58
# Name: count, dtype: int64

# %%
df.describe(include="O")
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_20240\504318277.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include="O")
#        Product_Name     Category          Store   City Payment_Method  \
# count           800          800            800    800            800
# unique           21            6              9     11              6
# top         Unknown  Electronics  Digital World  Tanta    Credit Card
# freq             80          151            106     85            170
#
#        Customer_Gender
# count              800
# ...

# %%
print(df.groupby('Payment_Method')['Rating'].mean().sort_values(ascending=False))
# Out:
# Payment_Method
# Instapay         3.181618
# Debit Card       3.086897
# Cash             2.956429
# Credit Card      2.925294
# Vodafone Cash    2.900775
# Unknown          2.866250
# Name: Rating, dtype: float64

# %%
df["Product_Name"].value_counts()
# Out:
# Product_Name
# Unknown        80
# Printer        47
# Mouse          45
# Laptop         42
# Hard Drive     42
# SSD            42
# USB Cable      40
# Speaker        40
# Microphone     39
# Chair          35
# Phone          35
# Smart Watch    35
# Monitor        34
# Tablet         34
# Webcam         33
# Keyboard       32
# Desk           32
# Camera         31
# Power Bank     28
# Headphones     27
# Router         27
# Name: count, dtype: int64

# %%
df["Payment_Method"].value_counts()
# Out:
# Payment_Method
# Credit Card      170
# Debit Card       145
# Cash             140
# Instapay         136
# Vodafone Cash    129
# Unknown           80
# Name: count, dtype: int64
